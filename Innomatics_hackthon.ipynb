# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("movies.csv")

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %% [markdown]
# # What is the shape of "movies.csv"?

# %%
df.shape
# Out:
# (9742, 3)

# %% [markdown]
# # What is the shape of "ratings.csv"?

# %%
df1=pd.read_csv("ratings.csv")
df1.shape
# Out:
# (100836, 4)

# %%
df1
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# # How many unique "userId" are available in "ratings.csv"?

# %%
df1['userId'].nunique()
# Out:
# 610

# %% [markdown]
# # Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

# %%
 df[df['title'] == 'Matrix, The (1999)']
# Out:
#       movieId               title                  genres
# 1939     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller

# %%
mat= df3[df3['movieId'] ==2571]
mat
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %% [markdown]
# # Which movie has recieved maximum number of user ratings?

# %%
max_rated_movie_id = movie_ratings_count.idxmax()
max_rated_movie_id
# Out:
# 356

# %%
max_rated_movie_info = df[df['movieId'] == max_rated_movie_id]

# %%
print(max_rated_movie_info)
# Out:
#      movieId                title                    genres
# 314      356  Forrest Gump (1994)  Comedy|Drama|Romance|War

# %% [markdown]
# # What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
 df[df['title'] ==  "Terminator 2: Judgment Day (1991)"]
# Out:
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi

# %%
term2=df1.groupby('movieId').get_group(589)

# %%
term2['rating'].mean()
# Out:
# 3.970982142857143

# %% [markdown]
# # How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
 df[df['title'] ==  "Fight Club (1999)"]
# Out:
#       movieId              title                       genres
# 2226     2959  Fight Club (1999)  Action|Crime|Drama|Thriller

# %%
fight=df1.groupby('movieId').get_group(2959)

# %%
fight
# Out:
#        userId  movieId  rating   timestamp
# 192         1     2959     5.0   964983282
# 458         4     2959     2.0   945078528
# 1134       10     2959     0.5  1455356582
# 1479       15     2959     2.5  1510571747
# 1635       16     2959     3.5  1377476874
# ...       ...      ...     ...         ...
# 95893     601     2959     5.0  1441639461
# 96788     603     2959     4.0   963176105
# 97835     606     2959     5.0  1171231517
# 99107     608     2959     5.0  1117336631
# 99699     610     2959     5.0  1479541966
#
# [218 rows x 4 columns]

# %%
fight['rating'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Mandetory operations

# %%
df1
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
grouped_ratings = df1.groupby('movieId')['rating'].agg(['count', 'mean']).reset_index()

# %%
grouped_ratings
# Out:
#       movieId  count      mean
# 0           1    215  3.920930
# 1           2    110  3.431818
# 2           3     52  3.259615
# 3           4      7  2.357143
# 4           5     49  3.071429
# ...       ...    ...       ...
# 9719   193581      1  4.000000
# 9720   193583      1  3.500000
# 9721   193585      1  3.500000
# 9722   193587      1  3.500000
# 9723   193609      1  4.000000
#
# [9724 rows x 3 columns]

# %%
merged_df = pd.merge(df, grouped_ratings, on='movieId', how='inner')

# %%
merged_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# ...

# %%
filtered_movies = merged_df[merged_df['count'] > 50]

# %%
filtered_movies
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# 5                           Action|Crime|Thriller    102  3.946078
# ...

# %% [markdown]
# # Which movie is the most popular based on  average user ratings?
# *

# %%
filtered_movies.sort_values(by='mean',ascending=False).head(1)
# Out:
#      movieId                             title       genres  count      mean
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama    317  4.429022

# %% [markdown]
# # Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
filtered_movies.sort_values(by='count',ascending=False).head(10)
# Out:
#       movieId                                      title  \
# 314       356                        Forrest Gump (1994)
# 277       318           Shawshank Redemption, The (1994)
# 257       296                        Pulp Fiction (1994)
# 510       593           Silence of the Lambs, The (1991)
# 1938     2571                         Matrix, The (1999)
# 224       260  Star Wars: Episode IV - A New Hope (1977)
# 418       480                       Jurassic Park (1993)
# 97        110                          Braveheart (1995)
# 507       589          Terminator 2: Judgment Day (1991)
# 461       527                    Schindler's List (1993)
#
#                                 genres  count      mean
# 314           Comedy|Drama|Romance|War    329  4.164134
# 277                        Crime|Drama    317  4.429022
# 257        Comedy|Crime|Drama|Thriller    307  4.197068
# 510              Crime|Horror|Thriller    279  4.161290
# ...

# %% [markdown]
# # webscraping script

# %%
df3=pd.read_csv("links.csv")

# %%
df3
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
links_df = pd.read_csv('links.csv')

# %%
links_df
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies_with_imdb_ids = pd.merge(filtered_movies, links_df, on='movieId', how='inner')

# %%
movies_with_imdb_ids
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %%
df8=movies_with_imdb_ids
df8
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text, 'html.parser')
    imdb_rating = soup.find('span', attrs={'data-testid': 'hero-rating-bar__score'})
    return imdb_rating.text if imdb_rating else np.nan

# %%
import pandas as pd

# Assuming movies_with_imdb_ids is your DataFrame
movies_with_imdb_ids['imdb_rating'] = movies_with_imdb_ids['imdbId'].apply(scrapper)

# Display the updated DataFrame
print(movies_with_imdb_ids)

# %%
#web scrapping not working i tried it for 1 hour but its just running so ..

# %%
# i take imdb ratings from other dataset

# %%
print(scrapper('114709'))
# Out:
# nan

# %%
#see its not working
from imdb import IMDb

ia = IMDb()
movie = ia.get_movie(114709)
rating = movie.data['rating']

# %%
import pandas as pd
from imdb import IMDb

# Assuming 'movies_df' is your DataFrame
ia = IMDb()

def get_imdb_rating(imdb_id):
    try:
        movie = ia.get_movie(imdb_id)
        return movie.data.get('rating')
    except Exception as e:
        print(f"Error fetching data for {imdb_id}: {e}")
        return None

# %%
# Apply the function to the 'imdb_id' column and create a new column 'imdb_rating'
df8['imdb_rating'] = df8['imdbId'].apply(get_imdb_rating)

# Display the updated DataFrame
print(df8)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[269], line 2
#       1 # Apply the function to the 'imdb_id' column and create a new column 'imdb_rating'
# ----> 2 df8['imdb_rating'] = df8['imdbId'].apply(get_imdb_rating)
#       4 # Display the updated DataFrame
#       5 print(df8)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
# ...

# %%
rating
# Out:
# 8.3

# %%
# !pip install IMDbPY
# Out:
# ...
#      ---------------------------------------- 0.0/297.2 kB ? eta -:--:--
#      - -------------------------------------- 10.2/297.2 kB ? eta -:--:--
#      ------- ----------------------------- 61.4/297.2 kB 825.8 kB/s eta 0:00:01
#      ---------------------- --------------- 174.1/297.2 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 297.2/297.2 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from imdb import IMDb

# Assuming 'df8' is your DataFrame
ia = IMDb()

def get_imdb_rating(imdb_id):
    try:
        movie = ia.get_movie(imdb_id)
        return movie.data.get('rating')
    except Exception as e:
        print(f"Error fetching data for {imdb_id}: {e}")
        return None

# Create a new column 'imdb_rating' and fill it with IMDb ratings
df8['imdb_rating'] = None  # Initialize the column with None

# Iterate over rows and update 'imdb_rating' column
for index, row in df8.iterrows():
    imdb_id = row['imdbId']
    rating = get_imdb_rating(imdb_id)
    df8.at[index, 'imdb_rating'] = rating
    
    print(f"IMDb Rating for {imdb_id}: {rating}")

# Display the updated DataFrame
print(df8)
# Out:
# IMDb Rating for 114709: 8.3
# IMDb Rating for 113497: 7.1
# IMDb Rating for 113228: 6.6
# IMDb Rating for 113277: 8.3
# IMDb Rating for 114319: 6.3
# IMDb Rating for 113189: 7.2
# IMDb Rating for 112346: 6.8
# IMDb Rating for 112641: 8.2
# IMDb Rating for 114388: 7.7
# IMDb Rating for 112281: 6.4
# IMDb Rating for 113161: 6.9
# IMDb Rating for 113627: 7.5
# IMDb Rating for 114746: 8.0
# IMDb Rating for 112431: 6.9
# IMDb Rating for 112818: 7.5
# IMDb Rating for 112697: 6.9
# IMDb Rating for 114369: 8.6
# IMDb Rating for 114148: 6.7
# IMDb Rating for 114814: 8.5
# IMDb Rating for 113862: 7.3
# IMDb Rating for 116367: 7.2
# IMDb Rating for 115759: 6.1
# IMDb Rating for 116483: 7.0
# IMDb Rating for 112573: 8.3
# IMDb Rating for 75314: 8.2
# IMDb Rating for 115685: 7.2
# IMDb Rating for 112442: 6.8
# IMDb Rating for 112384: 7.7
# IMDb Rating for 112462: 5.4
# IMDb Rating for 112642: 6.2
# IMDb Rating for 112715: 5.3
# IMDb Rating for 112740: 7.3
# IMDb Rating for 112851: 7.1
# ...

# %%
df8
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %%
df8.columns
# Out:
# Index(['movieId', 'title', 'genres', 'count', 'mean', 'imdbId', 'tmdbId',
#        'imdb_url', 'imdb_rating'],
#       dtype='object')

# %% [markdown]
# # Mention the movieId of the movie which has the highest IMDB rating

# %%
df8.sort_values(by='imdb_rating',ascending=False).head(1)
# Out:
#     movieId                             title       genres  count      mean  \
# 53      318  Shawshank Redemption, The (1994)  Crime|Drama    317  4.429022
#
#     imdbId  tmdbId                                   imdb_url imdb_rating
# 53  111161   278.0  https://www.imdb.com/title/111161/reviews         9.3

# %% [markdown]
# # Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
df8.sort_values(by='imdb_rating',ascending=False).head(15)
# Out:
#      movieId                                              title  \
# 53       318                   Shawshank Redemption, The (1994)
# 117      858                              Godfather, The (1972)
# 146     1203                                12 Angry Men (1957)
# 364     7153  Lord of the Rings: The Return of the King, The...
# 156     1221                     Godfather: Part II, The (1974)
# 86       527                            Schindler's List (1993)
# 407    58559                            Dark Knight, The (2008)
# 49       296                                Pulp Fiction (1994)
# 331     4993  Lord of the Rings: The Fellowship of the Ring,...
# 61       356                                Forrest Gump (1994)
# 273     2959                                  Fight Club (1999)
# 145     1201  Good, the Bad and the Ugly, The (Buono, il bru...
# 424    79132                                   Inception (2010)
# 345     5952      Lord of the Rings: The Two Towers, The (2002)
# ...
